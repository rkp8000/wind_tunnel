# %% [markdown]
# ### Figures for final paper

# %%
import pdb
# %matplotlib inline
from view.final_figures import example_traj_and_crossings

f = example_traj_and_crossings(
    SEED=2,
    EXPT_ID='fruitfly_0.4mps_checkerboard_floor',
    TRAJ_NUMBER='s20120924_172239_18773',
    TRAJ_START_TP=1000,
    TRAJ_END_TP=3000,
    CROSSING_GROUP='fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
    N_CROSSINGS=30,
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    MIN_PEAK_CONC=100,
    TS_BEFORE_3D=10, TS_AFTER_3D=60,
    TS_BEFORE_HEADING=20, TS_AFTER_HEADING=80,
    FIG_SIZE=(14, 14),
    SCATTER_SIZE=10,
    CYL_STDS=2, CYL_COLOR='r', CYL_ALPHA=0.15,
    EXPT_LABEL=None,
    FONT_SIZE=20)
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# %matplotlib inline
from view.final_figures.supplementary import response_discrimination_via_thresholds

f = response_discrimination_via_thresholds(
    RESPONSE_VAR='heading_xyz',
    CROSSING_GROUP_IDS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th0.1',
        'fruitfly_0.4mps_checkerboard_floor_on_th0.1',
        'fruitfly_0.6mps_checkerboard_floor_on_th0.1',
        'mosquito_0.4mps_checkerboard_floor_on_th401',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.3mps_checkerboard_floor_on_th0.1': 'fly 0.3 m/s',
        'fruitfly_0.4mps_checkerboard_floor_on_th0.1': 'fly 0.4 m/s',
        'fruitfly_0.6mps_checkerboard_floor_on_th0.1': 'fly 0.6 m/s',
        'mosquito_0.4mps_checkerboard_floor_on_th401': 'mosq 0.4 m/s',
    },
    CROSSING_GROUP_X_LIMS={
        'fruitfly_0.3mps_checkerboard_floor_on_th0.1': (0, 150),
        'fruitfly_0.4mps_checkerboard_floor_on_th0.1': (0, 200),
        'fruitfly_0.6mps_checkerboard_floor_on_th0.1': (0, 200),
        'mosquito_0.4mps_checkerboard_floor_on_th401': (400, 1200),
    },
    AX_SIZE=(10, 5),
    FONT_SIZE=20,
)
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# %matplotlib inline
from view.final_figures import heading_concentration_dependence

fig_2 = heading_concentration_dependence(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosquito',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    T_BEFORE=0.2,
    T_AFTER=0.8,
    T_MODELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 0.3,
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 0.5,
    },
    CROSSING_GROUP_EXAMPLE_ID='fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
    FIG_SIZE=(15, 10),
    CROSSING_GROUP_COLORS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'k',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'r',
    },
    SCATTER_SIZE=10, SCATTER_COLOR='k', SCATTER_ALPHA=.3,
    FONT_SIZE=20)
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# 'Model fit analysis for "fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0":'
# {'f': 14.729694293868397,
#  'h_vs_c_coef': -577.64949891502226,
#  'n': 2322,
#  'p_val': 0.00012740162865643168,
#  'rho': -0.29316691057057104,
#  'rss_binary': 2484068.2215055218,
#  'rss_binary_linear': 2468355.9790767222,
#  'threshold_binary': 0.013663371863117873,
#  'threshold_binary_linear': 0.0011016504182509508}
# 'Model fit analysis for "mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0":'
# {'f': 3.2059310000847629,
#  'h_vs_c_coef': -294.56492620286292,
#  'n': 281,
#  'p_val': 0.074479681545342569,
#  'rho': -0.13892892927234332,
#  'rss_binary': 395632.46190826624,
#  'rss_binary_linear': 391040.3433767088,
#  'threshold_binary': 0.040074946768060837,
#  'threshold_binary_linear': 0.040074946768060837}
# ...

# %% [markdown]
# ### Model fit parameters:
#
# concentration-mapping: 0.0476% ethanol = 526 concentration units
#
# #### Fly 0.3 m/s
#
# 'p_val': 0.0011153028899315576
#
# 'threshold_binary': 85.275300000000001
#
# 'threshold_binary_linear': 37.368250000000003 (0.003% ethanol)
#
# approx range: 2.5 - 4.5 cm from plume center
#
# #### Fly 0.4 m/s
#
# 'p_val': 0.00012740162865643168
#
# 'threshold_binary': 150.98599999999999
#
# 'threshold_binary_linear': 12.1737 (0.001% ethanol)
#
# approx range: 2.5 - 4 cm from plume center
#
# #### Fly 0.6 m/s
#
# 'p_val': < 10^-11
#
# 'threshold_binary': 49.395249999999997,
#
# 'threshold_binary_linear': 12.179449999999999 (0.001% ethanol)
#
# approx range: 2 - 2.5 cm from plume center
#
#
# #### Mosq 0.4 m/s
#
# 'p_val': 0.074479681545342569
#
# 'threshold_binary': 442.84500000000003,
#
# 'threshold_binary_linear': 442.84500000000003 (ppm CO2)
#
# approx range (uw end): 1.5 - 3.5 cm from plume center

# %%
import pdb
# %matplotlib inline
import numpy as np
from view.final_figures import early_vs_late_heading_timecourse

f_1, f_2 = early_vs_late_heading_timecourse(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.3 m/s)',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.4 m/s)',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.6 m/s)',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosq. (0.4 m/s)',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    MAX_CROSSINGS_EARLY=2,
    SUBTRACT_INITIAL_HEADING=True,
    T_BEFORE=0.2,
    T_AFTER=0.8,
    AX_SIZE=(7, 5),
    AX_GRID=(2, 2),
    EARLY_LATE_COLORS={'early': 'b', 'late': 'g'},
    ALPHA=0.2,
    P_VAL_COLOR='k',
    P_VAL_Y_LIM=(0, 0.2),
    LEGEND_CROSSING_GROUP_ID='fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
    X_0_BINS=np.linspace(-0.01, 0.71, 31, endpoint=True),
    FONT_SIZE=20)
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
import pdb
# %matplotlib inline
import numpy as np
from view.final_figures import infotaxis_analysis

f = infotaxis_analysis(
    WIND_TUNNEL_CG_IDS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        ],
    INFOTAXIS_WIND_SPEED_CG_IDS=[
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        ],
    MAX_CROSSINGS=np.inf,
    INFOTAXIS_HISTORY_DEPENDENCE_CG_IDS=[
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.08_mosquito_0.4mps_checkerboard_floor_odor_on_th_430_hsmoothing_3',
        ],
    MAX_CROSSINGS_EARLY=2,
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    X_0_MIN_SIM=0,
    X_0_MAX_SIM=65,
    X_0_MIN_SIM_HISTORY=15,
    X_0_MAX_SIM_HISTORY=50,
    T_BEFORE_EXPT=0.2,
    T_AFTER_EXPT=0.8,
    TS_BEFORE_SIM=5,
    TS_AFTER_SIM=25,
    HEADING_SMOOTHING_SIM=3,
    HEAT_MAP_EXPT_ID='fruitfly_0.4mps_checkerboard_floor',
    HEAT_MAP_SIM_ID='wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.4mps_checkerboard_floor_odor_on',
    N_HEAT_MAP_TRAJS=None,
    X_BINS=np.linspace(-0.3, 1, 67, endpoint=True),
    Y_BINS=np.linspace(-0.15, 0.15, 17, endpoint=True),
    FIG_SIZE=(15, 17),
    FONT_SIZE=20,
    EXPT_LABELS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.3 m/s',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.4 m/s',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.6 m/s',
        },
    EXPT_COLORS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'b',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'g',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'r',
        },
    SIM_LABELS={
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.3 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.4 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.6 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.08_mosquito_0.4mps_checkerboard_floor_odor_on_th_430_hsmoothing_3': 'mosq. 0.4 m/s',
    })
# Out:
# 14774 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"
# 10532 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"
# 1130 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.08_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"

# %%
# %matplotlib inline
import numpy as np
from view.figures.simple_tracking_analysis import crossing_triggered_headings_early_late

fig = crossing_triggered_headings_early_late(
    SEED=0,
    
    N_TRAJS=500,
    DURATION=20, DT=0.01,
    START_POS_RANGE=[(-1, 1), (-1, 1)],
    
    PL_CONC=195,
    PL_MEAN=np.array([0., 0]),
    PL_K=np.array([[0.0139, 0], [0, 0.024]]),
    
    TAU=1., NOISE=5., BIAS=2., AGENT_THRESHOLD=10,
    HIT_TRIGGER='peak', HIT_INFLUENCE=0.3,
    K_0=np.array([[1., 0], [0, 1]]),
    K_S=np.array([[0.5, 0], [0, 0.5]]),
    
    ANALYSIS_THRESHOLD=10, H_MIN_PEAK=60, H_MAX_PEAK=120,
    EARLY_LESS_THAN=3,
    SUBTRACT_PEAK_HEADING=True, T_BEFORE=0.2, T_AFTER=1.)

# %% [markdown]
# Plume parameters
#
# ```python
# PLUME_PARAMS_DICT = {
#     'fruitfly_0.3mps_checkerboard_floor': {
#         'max_conc': 194.4013571501637,
#         'threshold': 10,
#         'ymean': -0.01686711918990497,
#         'zmean': -0.024448968890361408,
#         'ystd': 0.013907665641150927,
#         'zstd': 0.024051865551085332,
#     },
#     'fruitfly_0.4mps_checkerboard_floor': {
#         'max_conc': 526.5611158275608,
#         'threshold': 10,
#         'ymean': 0.010397528868787908,
#         'zmean': 0.021053005635139854,
#         'ystd': 0.011163543244851111,
#         'zstd': 0.012783432241805101,
#     },
#     'fruitfly_0.6mps_checkerboard_floor': {
#         'max_conc': 470.45545552729538,
#         'threshold': 10,
#         'ymean': 0.0046019902473019899,
#         'zmean': 0.051356187443552505,
#         'ystd': 0.0084829247732408405,
#         'zstd': -0.0091643524066678372,
#     },
#     'mosquito_0.4mps_checkerboard_floor': {
#         'Q': -0.26618286981003886,
#         'u': 0.4,
#         'u_star': 0.06745668765535813,
#         'alpha_y': -0.066842568000323691,
#         'alpha_z': 0.14538827993452938,
#         'x_source': -0.64790143304753445,
#         'y_source': .003,
#         'z_source': .011,
#         'bkgd': 400,
#         'threshold': 450,
#     }
# }
# ```

# %% [markdown]
# ### equation for CO2 plume:
#
# $$c(x, y, z) = \cfrac{Qu}{2\pi\alpha_y\alpha_z u_*^2(x - x_s)^2}
# \exp\left(-\cfrac{(y - y_s)^2u^2}{2\alpha_y^2u_*^2(x-x_s)^2} -\cfrac{(z - z_s)^2u^2}{2\alpha_z^2u_*^2(x-x_s)^2}\right)$$

# %% [markdown]
# At $x = -0.3 cm$:
#
# $$

# %%
import numpy as np

Q = 0.26618286981003886
u = 0.4
pi = 3.14159265359
alpha_y = 0.066842568000323691
alpha_z = 0.14538827993452938
u_star = 0.06745668765535813
x_s = -0.64790143304753445

x_uw = -0.3
x_dw = 1

factor_uw = (Q*u) / (2*pi*alpha_y*alpha_z*(u_star**2)*(x_uw - x_s)**2)
std_y_uw = np.sqrt((alpha_y**2)*(u_star**2)*((x_uw - x_s)**2)/(u**2))
std_z_uw = np.sqrt((alpha_z**2)*(u_star**2)*((x_uw - x_s)**2)/(u**2))

print('uw factor', factor_uw)
print('uw std_y', std_y_uw)
print('uw std_z', std_z_uw)

factor_dw = (Q*u) / (2*pi*alpha_y*alpha_z*(u_star**2)*(x_dw - x_s)**2)
std_y_dw = np.sqrt((alpha_y**2)*(u_star**2)*((x_dw - x_s)**2)/(u**2))
std_z_dw = np.sqrt((alpha_z**2)*(u_star**2)*((x_dw - x_s)**2)/(u**2))

print('dw factor', factor_dw)
print('dw std_y', std_y_dw)
print('dw std_z', std_z_dw)
# Out:
# ('uw factor', 3166.0315724155253)
# ('uw std_y', 0.0039216999709539126)
# ('uw std_z', 0.0085300315390863211)
# ('dw factor', 141.11241158422678)
# ('dw std_y', 0.018575879223913492)
# ('dw std_z', 0.040404119851039602)
