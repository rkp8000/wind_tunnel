# %%
# %matplotlib inline
from view.figures.kinematic_distributions import show_distributions

fig = show_distributions(
    EXPERIMENTS=[
        'fruitfly_0.3mps_checkerboard_floor',
        'fruitfly_0.4mps_checkerboard_floor',
        'fruitfly_0.6mps_checkerboard_floor'
    ],
    VARIABLES=['velocity_x', 'velocity_a'],
    ODOR_STATES=['on', 'none'],
    AX_GRID=(3, 2))

# %% [markdown]
# ### Fig S1: Velocity distributions

# %%
import pdb
# %matplotlib inline
from view.final_figures.supplementary import crossing_number_distributions

fig = crossing_number_distributions(
    CROSSING_GROUPS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th410'],
    AX_GRID=(2, 2))
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### Fig S2: Distribution of number of crossings per trajectory

# %%
import pdb
# %matplotlib inline
from view.final_figures.supplementary import trajectory_duration_distributions

fig = trajectory_duration_distributions(
    EXPERIMENTS=[
        'fruitfly_0.3mps_checkerboard_floor',
        'fruitfly_0.4mps_checkerboard_floor',
        'fruitfly_0.6mps_checkerboard_floor',
        'mosquito_0.4mps_checkerboard_floor'
    ],
    AX_GRID=(2, 2),
)

# %% [markdown]
# ### Fig S3: Distribution of trajectory durations

# %%
# %matplotlib inline
from view.final_figures.supplementary import heading_duration_dependence

heading_duration_dependence(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosquito',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    T_BEFORE=0.2,
    T_AFTER=0.8,
    T_MODELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 0.3,
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 0.5,
    },
    CROSSING_GROUP_EXAMPLE_ID='fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
    FIG_SIZE=(15, 10),
    CROSSING_GROUP_COLORS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'k',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'r',
    },
    SCATTER_SIZE=10, SCATTER_COLOR='k', SCATTER_ALPHA=.3,
    FONT_SIZE=20);
# Out:
# 'Model fit analysis for "fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0":'
# {'f': 13.82491087976234,
#  'h_vs_d_coef': 15.435582759173153,
#  'n': 1817,
#  'p_val': 0.00020676910014161276,
#  'rho': 0.049489384828381701,
#  'rss_binary': 2308354.689445815,
#  'rss_binary_linear': 2290847.359109262,
#  'threshold_binary': 0.065000000000000002,
#  'threshold_binary_linear': 0.075000000000000011}
# 'Model fit analysis for "mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0":'
# {'f': 0.52188195286040306,
#  'h_vs_d_coef': 9.9714853054215808,
#  'n': 229,
#  'p_val': 0.47080373971858591,
#  'rho': 0.016774456325794732,
#  'rss_binary': 305082.39051076595,
#  'rss_binary_linear': 304363.64890230959,
#  'threshold_binary': 0.044999999999999998,
#  'threshold_binary_linear': 0.044999999999999998}

# %% [markdown]
# ### Fig S4.1: Relationship between duration of crossing and heading at different time points post-crossing

# %% [markdown]
# Time since crossing is measured relative to "plume-exit", i.e., time point at which concentration dropped below a threshold. Shading indicates 2.5/97.5% confidence intervals. Crossing threshold was 10 for fruit fly group, and 430 for mosquito group.

# %%
# %matplotlib inline
from view.final_figures.supplementary import heading_duration_dependence

heading_duration_dependence(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500': 'fly',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosquito',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    T_BEFORE=0.2,
    T_AFTER=0.8,
    T_MODELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500': 0.3,
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 0.5,
    },
    CROSSING_GROUP_EXAMPLE_ID='fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500',
    FIG_SIZE=(15, 10),
    CROSSING_GROUP_COLORS={
        'fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500': 'k',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'r',
    },
    SCATTER_SIZE=10, SCATTER_COLOR='k', SCATTER_ALPHA=.3,
    FONT_SIZE=20);
# Out:
# 'Model fit analysis for "fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500":'
# {'f': 14.468135838378176,
#  'h_vs_d_coef': 27.897008271322147,
#  'n': 1618,
#  'p_val': 0.0001478772698267905,
#  'rho': 0.053702131031923693,
#  'rss_binary': 1733311.8559479967,
#  'rss_binary_linear': 1717874.3162210728,
#  'threshold_binary': 0.315,
#  'threshold_binary_linear': 0.084999999999999992}
# 'Model fit analysis for "mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0":'
# {'f': 0.52188195286040306,
#  'h_vs_d_coef': 9.9714853054215808,
#  'n': 229,
#  'p_val': 0.47080373971858591,
#  'rho': 0.016774456325794732,
#  'rss_binary': 305082.39051076595,
#  'rss_binary_linear': 304363.64890230959,
#  'threshold_binary': 0.044999999999999998,
#  'threshold_binary_linear': 0.044999999999999998}

# %% [markdown]
# ### Fig S4.2: Same as Fig S4.1 but using a higher threshold for crossing identification

# %% [markdown]
# Time since crossing is measured relative to "plume-exit", i.e., time point at which concentration dropped below a threshold. Shading indicates 2.5/97.5% confidence intervals. Crossing threshold was 40 for fruit fly group, and 430 for mosquito group.

# %% [markdown]
# ### History dependence of crossing-triggered heading when x-position is accounted for

# %%
# %matplotlib inline
import pdb
import numpy as np
from view.final_figures.supplementary import early_vs_late_heading_timecourse_x0_accounted_for

early_vs_late_heading_timecourse_x0_accounted_for(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.3 m/s)',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.4 m/s)',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.6 m/s)',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosq. (0.4 m/s)',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    CROSSING_NUMBER_MAX=5,
    MAX_CROSSINGS_EARLY=2,
    SUBTRACT_INITIAL_HEADING=True,
    T_BEFORE=0,
    T_AFTER=0.8,
    SCATTER_INTEGRATION_WINDOW=[0.6, 0.7],
    AX_SIZE=(7, 5),
    AX_GRID=(2, 2),
    EARLY_LATE_COLORS={'early': 'b', 'late': 'g'},
    ALPHA=0.2,
    P_VAL_COLOR='k',
    P_VAL_Y_LIM=(0, 0.2),
    LEGEND_CROSSING_GROUP_ID='fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
    FONT_SIZE=16);

# %% [markdown]
# ### Fig S5.1: History- and crossing-number-dependence of heading after accounting for x position
# The top four plots show the time-course of the heading residual values relative to the plume crossing for both early and late groups, with the dotted line indicating the probability that a difference as large as that observed between the two distributions at each time point would have arisen by chance (KS test). The scatter plots show crossing x-position on the x-axis and the change from zero of the original heading change on the y-axis (averaged between 600 and 700 ms post crossing). The colors indicate crossing number. The titles show the partial correlation coefficient of this integrated heading value and crossing number, given the x-position of the crossing, with the P-value also shown up to 3 decimal places.

# %%
# %matplotlib inline
import numpy as np
from view.final_figures.supplementary import early_vs_late_heading_timecourse_x0_accounted_for

early_vs_late_heading_timecourse_x0_accounted_for(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.3 m/s)',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.4 m/s)',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.6 m/s)',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosq. (0.4 m/s)',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    CROSSING_NUMBER_MAX=5,
    MAX_CROSSINGS_EARLY=2,
    SUBTRACT_INITIAL_HEADING=True,
    T_BEFORE=0,
    T_AFTER=0.8,
    SCATTER_INTEGRATION_WINDOW=[0.3, 0.4],
    AX_SIZE=(7, 5),
    AX_GRID=(2, 2),
    EARLY_LATE_COLORS={'early': 'b', 'late': 'g'},
    ALPHA=0.2,
    P_VAL_COLOR='k',
    P_VAL_Y_LIM=(0, 0.2),
    LEGEND_CROSSING_GROUP_ID='fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
    FONT_SIZE=16);

# %% [markdown]
# ### Fig S5.2: Same as Fig S5.1 but with scatter plot showing heading integrated from 300 to 400 ms

# %% [markdown]
# ### Infotaxis with different diffusivities

# %%
import pdb
# %matplotlib inline
import numpy as np
from view.final_figures import infotaxis_analysis

f = infotaxis_analysis(
    WIND_TUNNEL_CG_IDS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        ],
    INFOTAXIS_WIND_SPEED_CG_IDS=[
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        ],
    MAX_CROSSINGS=np.inf,
    INFOTAXIS_HISTORY_DEPENDENCE_CG_IDS=[
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.02_mosquito_0.4mps_checkerboard_floor_odor_on_th_430_hsmoothing_3',
        ],
    MAX_CROSSINGS_EARLY=2,
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    X_0_MIN_SIM=0,
    X_0_MAX_SIM=65,
    X_0_MIN_SIM_HISTORY=15,
    X_0_MAX_SIM_HISTORY=50,
    T_BEFORE_EXPT=0.2,
    T_AFTER_EXPT=0.8,
    TS_BEFORE_SIM=5,
    TS_AFTER_SIM=25,
    HEADING_SMOOTHING_SIM=3,
    HEAT_MAP_EXPT_ID='fruitfly_0.4mps_checkerboard_floor',
    HEAT_MAP_SIM_ID='wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.4mps_checkerboard_floor_odor_on',
    N_HEAT_MAP_TRAJS=None,
    X_BINS=np.linspace(-0.3, 1, 67, endpoint=True),
    Y_BINS=np.linspace(-0.15, 0.15, 17, endpoint=True),
    FIG_SIZE=(15, 17),
    FONT_SIZE=20,
    EXPT_LABELS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.3 m/s',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.4 m/s',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.6 m/s',
        },
    EXPT_COLORS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'b',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'g',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'r',
        },
    SIM_LABELS={
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.3 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.4 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.6 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.02_mosquito_0.4mps_checkerboard_floor_odor_on_th_430_hsmoothing_3': 'mosq. 0.4 m/s',
    })
# Out:
# CONNECTED TO INFOTAXIS PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# 12155 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"
# 16821 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"
# 1825 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.02_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"

# %%
import pdb
# %matplotlib inline
import numpy as np
from view.final_figures import infotaxis_analysis

f = infotaxis_analysis(
    WIND_TUNNEL_CG_IDS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        ],
    INFOTAXIS_WIND_SPEED_CG_IDS=[
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        ],
    MAX_CROSSINGS=np.inf,
    INFOTAXIS_HISTORY_DEPENDENCE_CG_IDS=[
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3',
        'wind_tunnel_discretized_matched_r1000_d0.1_mosquito_0.4mps_checkerboard_floor_odor_on_th_430_hsmoothing_3',
        ],
    MAX_CROSSINGS_EARLY=2,
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    X_0_MIN_SIM=0,
    X_0_MAX_SIM=65,
    X_0_MIN_SIM_HISTORY=15,
    X_0_MAX_SIM_HISTORY=50,
    T_BEFORE_EXPT=0.2,
    T_AFTER_EXPT=0.8,
    TS_BEFORE_SIM=5,
    TS_AFTER_SIM=25,
    HEADING_SMOOTHING_SIM=3,
    HEAT_MAP_EXPT_ID='fruitfly_0.4mps_checkerboard_floor',
    HEAT_MAP_SIM_ID='wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.4mps_checkerboard_floor_odor_on',
    N_HEAT_MAP_TRAJS=None,
    X_BINS=np.linspace(-0.3, 1, 67, endpoint=True),
    Y_BINS=np.linspace(-0.15, 0.15, 17, endpoint=True),
    FIG_SIZE=(15, 17),
    FONT_SIZE=20,
    EXPT_LABELS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.3 m/s',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.4 m/s',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'fly 0.6 m/s',
        },
    EXPT_COLORS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'b',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'g',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'r',
        },
    SIM_LABELS={
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.3 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.4 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3': 'fly 0.6 m/s',
        'wind_tunnel_discretized_matched_r1000_d0.1_mosquito_0.4mps_checkerboard_floor_odor_on_th_430_hsmoothing_3': 'mosq. 0.4 m/s',
    })
# Out:
# 14517 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.3mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"
# 9860 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.4mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"
# 1068 crossings for infotaxis crossing group: "wind_tunnel_discretized_matched_r1000_d0.1_fruitfly_0.6mps_checkerboard_floor_odor_on_th_10_hsmoothing_3"

# %%
# %matplotlib inline
from view.final_figures.supplementary import bias_vs_n_crossings

fig = bias_vs_n_crossings(
    NS=range(10),
    SQRT_K_0=5,
    SQRT_K_S=2,
    BIAS=0.172212877199)
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
