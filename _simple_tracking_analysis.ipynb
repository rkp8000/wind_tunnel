# %%
# example trajectory
# %matplotlib inline
from view.figures.simple_tracking_analysis import example_trajectory_no_plume

fig = example_trajectory_no_plume(
    SEED=3,
    DURATION=10,
    DT=0.01,
    
    TAU=0.573219802614,
    NOISE=1.63018598472,
    BIAS=0.172212877199,
    
    BOUNDS=[(-1, .3), (-0.15, 0.15), (-0.15, 0.15)],
)

# %%
# optimization of model parameters
# %matplotlib inline
from view.figures.simple_tracking_analysis import optimize_model_params

fig = optimize_model_params(
    SEED=0,
    DURATION=100,
    DT=0.01,
    BOUNDS=[(-1, .3), (-0.15, 0.15), (-0.15, 0.15)],
    
    EXPERIMENT='fruitfly_0.4mps_checkerboard_floor',
    ODOR_STATE='on',
    MAX_TRAJS_EMPIRICAL=500,
    N_TIME_POINTS_EMPIRICAL=10000,
    
    SAVE_FILE_PREFIX='simple_model_empirical_data',
    INITIAL_PARAMS=[.3, 2.5, 0.5],  # [tau, noise, bias]
    MAX_ITERS=100)
# Out:
# performing optimization
# Optimization terminated successfully.
#          Current function value: 0.380641
#          Iterations: 54
#          Function evaluations: 119
# best params:
# tau = 0.573219802614
# noise = 1.63018598472
# bias = 0.172212877199

# %%
# example trajectory with a plume
# %matplotlib inline
import numpy as np
from view.figures.simple_tracking_analysis import example_trajectory_centerline_with_plume

fig = example_trajectory_centerline_with_plume(
    SEED=1,
    DURATION=20,
    DT=0.01,
    TAU=0.573219802614,
    NOISE=1.63018598472,
    BIAS=0.172212877199,
    THRESHOLD=10,
    HIT_INFLUENCE=2,
    TAU_MEMORY=5,
    K_0=1, K_S=0.3,
    BOUNDS=[(-1, .3), (-0.15, 0.15), (-0.15, 0.15)],
    
    PL_CONC=195,
    PL_MEAN=np.array([0., 0]),
    PL_STD=np.array([0.0139, 0.024]))
# Out:
# /Users/rkp/anaconda/envs/py2/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# %matplotlib inline
import numpy as np
from view.figures.simple_tracking_analysis import crossing_triggered_headings_all

fig = crossing_triggered_headings_all(
    SEED=1, N_TRAJS=200,
    
    DURATION=10,
    DT=0.01,
    TAU=0.573219802614,
    NOISE=1.63018598472,
    BIAS=0.172212877199,
    AGENT_THRESHOLD=10,
    HIT_INFLUENCE=1,
    TAU_MEMORY=np.inf,
    K_0=3, K_S=2,
    BOUNDS=[(-0.3, 1), (-0.15, 0.15), (-0.15, 0.15)],
    
    PL_CONC=195,
    PL_MEAN=np.array([0., 0]),
    PL_STD=np.array([0.0139, 0.024]),
    
    ANALYSIS_THRESHOLD=10, H_MIN_PEAK=60, H_MAX_PEAK=120,
    SUBTRACT_PEAK_HEADING=True, T_BEFORE=0.2, T_AFTER=1., Y_LIM=(-30, 30))
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# %matplotlib inline
import numpy as np
from view.figures.simple_tracking_analysis import crossing_triggered_headings_early_late

fig = crossing_triggered_headings_early_late(
    SEED=0, N_TRAJS=3000,
    
    DURATION=15,
    DT=0.01,
    TAU=0.573219802614,
    NOISE=1.63018598472,
    BIAS=0.172212877199,
    AGENT_THRESHOLD=10,
    HIT_INFLUENCE=1,
    TAU_MEMORY=np.inf,
    K_0=9, K_S=4,
    BOUNDS=[(-0.3, 1), (-0.15, 0.15), (-0.15, 0.15)],
    
    PL_CONC=195,
    PL_MEAN=np.array([0., 0]),
    PL_STD=np.array([0.0139, 0.024]),
    
    ANALYSIS_THRESHOLD=10, H_MIN_PEAK=60, H_MAX_PEAK=120, X_MIN_PEAK=0., X_MAX_PEAK=0.7,
    EARLY_LESS_THAN=3,
    SUBTRACT_PEAK_HEADING=True, T_BEFORE=0.2, T_AFTER=1.)
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# %matplotlib inline
import numpy as np
from view.figures.simple_tracking_analysis import crossing_triggered_headings_early_late

fig = crossing_triggered_headings_early_late(
    SEED=0, N_TRAJS=3000,
    
    DURATION=15,
    DT=0.01,
    TAU=0.573219802614,
    NOISE=1.63018598472,
    BIAS=0.172212877199,
    AGENT_THRESHOLD=10,
    HIT_INFLUENCE=1,
    TAU_MEMORY=np.inf,
    K_0=25, K_S=4,
    BOUNDS=[(-0.3, 1), (-0.15, 0.15), (-0.15, 0.15)],
    
    PL_CONC=526,
    PL_MEAN=np.array([0.0104, 0.02105]),
    PL_STD=np.array([0.01116, 0.01278]),
    
    ANALYSIS_THRESHOLD=10, H_MIN_PEAK=60, H_MAX_PEAK=120, X_MIN_PEAK=0., X_MAX_PEAK=0.7,
    EARLY_LESS_THAN=3,
    SUBTRACT_PEAK_HEADING=True, T_BEFORE=0.2, T_AFTER=1.)

# %%
# %matplotlib inline
import numpy as np
from view.figures.simple_tracking_analysis import crossing_triggered_headings_early_late

fig = crossing_triggered_headings_early_late(
    SEED=1, N_TRAJS=3000,
    
    DURATION=15,
    DT=0.01,
    TAU=0.573219802614,
    NOISE=1.63018598472,
    BIAS=0.172212877199,
    AGENT_THRESHOLD=10,
    HIT_INFLUENCE=1,
    TAU_MEMORY=15,
    K_0=25, K_S=4,
    BOUNDS=[(-0.3, 1), (-0.15, 0.15), (-0.15, 0.15)],
    
    PL_CONC=195,
    PL_MEAN=np.array([0., 0]),
    PL_STD=np.array([0.0139, 0.024]),
    
    ANALYSIS_THRESHOLD=10, H_MIN_PEAK=60, H_MAX_PEAK=120, X_MIN_PEAK=0., X_MAX_PEAK=0.7,
    EARLY_LESS_THAN=3,
    SUBTRACT_PEAK_HEADING=True, T_BEFORE=0.2, T_AFTER=1.)

# %%
# %matplotlib inline
import numpy as np
from view.figures.simple_tracking_analysis import crossing_triggered_headings_early_late

fig = crossing_triggered_headings_early_late(
    SEED=0, N_TRAJS=3000,
    
    DURATION=15,
    DT=0.01,
    TAU=0.573219802614,
    NOISE=1.63018598472,
    BIAS=0.172212877199,
    AGENT_THRESHOLD=10,
    HIT_INFLUENCE=1,
    TAU_MEMORY=5,
    K_0=9, K_S=4,
    BOUNDS=[(-0.3, 1), (-0.15, 0.15), (-0.15, 0.15)],
    
    PL_CONC=195,
    PL_MEAN=np.array([0., 0]),
    PL_STD=np.array([0.0139, 0.024]),
    
    ANALYSIS_THRESHOLD=10, H_MIN_PEAK=60, H_MAX_PEAK=120, X_MIN_PEAK=0., X_MAX_PEAK=0.7,
    EARLY_LESS_THAN=3,
    SUBTRACT_PEAK_HEADING=True, T_BEFORE=0.2, T_AFTER=1.)

# %%
# %matplotlib inline
import numpy as np
from view.figures.simple_tracking_analysis import crossing_triggered_headings_early_late_vary_param

fig  = crossing_triggered_headings_early_late_vary_param(
    SEED=0,
    SAVE_FILE='simple_tracker_param_sweep.npy',
    N_TRAJS=5000,
    DURATION=15, DT=0.01,
    TAU=0.573219802614,
    NOISE=1.63018598472,
    BIAS=0.172212877199,
    HIT_INFLUENCE=1,
    SQRT_K_0=5,
    VARIABLE_PARAMS=[
        {'threshold': 10, 'sqrt_k_s': 2, 'tau_memory': [np.inf, 15, 10, 5, 1]},
        {'tau_memory': 15, 'sqrt_k_s': 2, 'threshold': [10, 20, 50]},
    ],
    BOUNDS=[(-0.3, 1), (-0.15, 0.15), (-0.15, 0.15)],
    PL_CONC=526,
    PL_MEAN=np.array([0.0104, 0.02105]),
    PL_STD=np.array([0.01116, 0.01278]),
    H_MIN_PEAK=60, H_MAX_PEAK=120, X_MIN_PEAK=0., X_MAX_PEAK=0.7,
    EARLY_LESS_THAN=3,
    SUBTRACT_PEAK_HEADING=True, T_BEFORE=0.2, T_AFTER=1.,
    T_INT_START=0.2, T_INT_END=1., AX_GRID=(1, 3))
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# Results file not found. Running analysis...
# Variable params: {'threshold': 10, 'tau_memory': [inf, 15, 10, 5, 1], 'sqrt_k_s': 2}
# Variable params: {'threshold': [10, 20, 50], 'sqrt_k_s': 2, 'tau_memory': 15}
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
