# %% [markdown]
# # Auxiliary code (infotaxis simulations about half-way down)

# %% [markdown]
# ### Velocity distributions

# %%
# %matplotlib inline
from view.figures.kinematic_distributions import show_distributions

fig = show_distributions(
    EXPERIMENTS=[
        'fruitfly_0.3mps_checkerboard_floor',
        'fruitfly_0.4mps_checkerboard_floor',
        'fruitfly_0.6mps_checkerboard_floor'
    ],
    VARIABLES=['velocity_x', 'velocity_a'],
    ODOR_STATES=['on', 'none'],
    AX_GRID=(3, 2))

# %% [markdown]
# ### Distribution of number of crossings per trajectory

# %%
import pdb
# %matplotlib inline
from view.final_figures.supplementary import crossing_number_distributions

fig = crossing_number_distributions(
    CROSSING_GROUPS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th410'],
    AX_GRID=(2, 2))
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### Distribution of trajectory durations

# %%
import pdb
# %matplotlib inline
from view.final_figures.supplementary import trajectory_duration_distributions

fig = trajectory_duration_distributions(
    EXPERIMENTS=[
        'fruitfly_0.3mps_checkerboard_floor',
        'fruitfly_0.4mps_checkerboard_floor',
        'fruitfly_0.6mps_checkerboard_floor',
        'mosquito_0.4mps_checkerboard_floor'
    ],
    AX_GRID=(2, 2),
)

# %%
# %matplotlib inline
from view.final_figures.supplementary import heading_duration_dependence

heading_duration_dependence(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosquito',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    T_BEFORE=0.2,
    T_AFTER=0.8,
    T_MODELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 0.3,
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 0.5,
    },
    CROSSING_GROUP_EXAMPLE_ID='fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
    FIG_SIZE=(15, 10),
    CROSSING_GROUP_COLORS={
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'k',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'r',
    },
    SCATTER_SIZE=10, SCATTER_COLOR='k', SCATTER_ALPHA=.3,
    FONT_SIZE=20);
# Out:
# 'Model fit analysis for "fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0":'
# {'f': 13.82491087976234,
#  'h_vs_d_coef': 15.435582759173153,
#  'n': 1817,
#  'p_val': 0.00020676910014161276,
#  'rho': 0.049489384828381701,
#  'rss_binary': 2308354.689445815,
#  'rss_binary_linear': 2290847.359109262,
#  'threshold_binary': 0.065000000000000002,
#  'threshold_binary_linear': 0.075000000000000011}
# 'Model fit analysis for "mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0":'
# {'f': 0.52188195286040306,
#  'h_vs_d_coef': 9.9714853054215808,
#  'n': 229,
#  'p_val': 0.47080373971858591,
#  'rho': 0.016774456325794732,
#  'rss_binary': 305082.39051076595,
#  'rss_binary_linear': 304363.64890230959,
#  'threshold_binary': 0.044999999999999998,
#  'threshold_binary_linear': 0.044999999999999998}

# %% [markdown]
# Time since crossing is measured relative to "plume-exit", i.e., time point at which concentration dropped below a threshold. Shading indicates 2.5/97.5% confidence intervals. Crossing threshold was 10 for fruit fly group, and 430 for mosquito group.

# %%
# %matplotlib inline
from view.final_figures.supplementary import heading_duration_dependence

heading_duration_dependence(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500': 'fly',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosquito',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    T_BEFORE=0.2,
    T_AFTER=0.8,
    T_MODELS={
        'fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500': 0.3,
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 0.5,
    },
    CROSSING_GROUP_EXAMPLE_ID='fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500',
    FIG_SIZE=(15, 10),
    CROSSING_GROUP_COLORS={
        'fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500': 'k',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'r',
    },
    SCATTER_SIZE=10, SCATTER_COLOR='k', SCATTER_ALPHA=.3,
    FONT_SIZE=20);
# Out:
# 'Model fit analysis for "fruitfly_0.4mps_checkerboard_floor_on_th40.0_chosen40_500":'
# {'f': 14.468135838378176,
#  'h_vs_d_coef': 27.897008271322147,
#  'n': 1618,
#  'p_val': 0.0001478772698267905,
#  'rho': 0.053702131031923693,
#  'rss_binary': 1733311.8559479967,
#  'rss_binary_linear': 1717874.3162210728,
#  'threshold_binary': 0.315,
#  'threshold_binary_linear': 0.084999999999999992}
# 'Model fit analysis for "mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0":'
# {'f': 0.52188195286040306,
#  'h_vs_d_coef': 9.9714853054215808,
#  'n': 229,
#  'p_val': 0.47080373971858591,
#  'rho': 0.016774456325794732,
#  'rss_binary': 305082.39051076595,
#  'rss_binary_linear': 304363.64890230959,
#  'threshold_binary': 0.044999999999999998,
#  'threshold_binary_linear': 0.044999999999999998}

# %% [markdown]
# Time since crossing is measured relative to "plume-exit", i.e., time point at which concentration dropped below a threshold. Shading indicates 2.5/97.5% confidence intervals. Crossing threshold was 40 for fruit fly group, and 430 for mosquito group.

# %% [markdown]
# ### History dependence of crossing-triggered heading when x-position and flight time are accounted for

# %%
# %matplotlib inline
import pdb
import numpy as np
from view.final_figures.supplementary import early_vs_late_heading_timecourse_x0_and_t_flight_accounted_for

early_vs_late_heading_timecourse_x0_and_t_flight_accounted_for(
    CROSSING_GROUP_IDS=[
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0',
    ],
    CROSSING_GROUP_LABELS={
        'fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.3 m/s)',
        'fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.4 m/s)',
        'fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0': 'fly (0.6 m/s)',
        'mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0': 'mosq. (0.4 m/s)',
    },
    X_0_MIN=0.,
    X_0_MAX=0.7,
    H_0_MIN=60,
    H_0_MAX=120,
    CROSSING_NUMBER_MAX=5,
    MAX_CROSSINGS_EARLY=2,
    SUBTRACT_INITIAL_HEADING=True,
    T_BEFORE=0,
    T_AFTER=0.8,
    ADJUST_NS=True,
    SCATTER_INTEGRATION_WINDOW=[0.4, 0.5],
    AX_SIZE=(7, 5),
    AX_GRID=(2, 2),
    EARLY_LATE_COLORS={'early': 'b', 'late': 'g'},
    ALPHA=0.2,
    P_VAL_COLOR='k',
    P_VAL_Y_LIM=(0, 0.2),
    LEGEND_CROSSING_GROUP_ID='fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0',
    FONT_SIZE=16);
# Out:
# CONNECTED TO WIND TUNNEL PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# /Users/rkp/anaconda/envs/py2/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:703: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)
# CROSSING GROUP "fly (0.3 m/s)"
# CROSSING SUBSET "early"
# 783 CROSSINGS; 672 UNIQUE TRAJECTORIES
# CROSSING GROUP "fly (0.3 m/s)"
# CROSSING SUBSET "late"
# 766 CROSSINGS; 498 UNIQUE TRAJECTORIES
# COEFS (X_0, T_FLIGHT) FOR CROSSING GROUP fly (0.3 m/s)
# MEANS: (-16.40080, -0.07847)
# STDS: (8.78443, 0.24174)
# CROSSING GROUP "fly (0.4 m/s)"
# CROSSING SUBSET "early"
# 1158 CROSSINGS; 969 UNIQUE TRAJECTORIES
# CROSSING GROUP "fly (0.4 m/s)"
# CROSSING SUBSET "late"
# 828 CROSSINGS; 568 UNIQUE TRAJECTORIES
# COEFS (X_0, T_FLIGHT) FOR CROSSING GROUP fly (0.4 m/s)
# MEANS: (-16.82170, -0.48266)
# STDS: (10.55550, 0.15404)
# CROSSING GROUP "fly (0.6 m/s)"
# CROSSING SUBSET "early"
# 394 CROSSINGS; 347 UNIQUE TRAJECTORIES
# CROSSING GROUP "fly (0.6 m/s)"
# CROSSING SUBSET "late"
# 294 CROSSINGS; 213 UNIQUE TRAJECTORIES
# COEFS (X_0, T_FLIGHT) FOR CROSSING GROUP fly (0.6 m/s)
# MEANS: (-16.76112, -0.18063)
# STDS: (17.25629, 0.05436)
# CROSSING GROUP "mosq. (0.4 m/s)"
# CROSSING SUBSET "early"
# 125 CROSSINGS; 106 UNIQUE TRAJECTORIES
# CROSSING GROUP "mosq. (0.4 m/s)"
# CROSSING SUBSET "late"
# 143 CROSSINGS; 95 UNIQUE TRAJECTORIES
# COEFS (X_0, T_FLIGHT) FOR CROSSING GROUP mosq. (0.4 m/s)
# MEANS: (-24.74662, 0.01540)
# STDS: (14.27100, 0.39026)
# MAKING PLOT FOR CG "fruitfly_0.3mps_checkerboard_floor_on_th10.0_chosen0"
# 783 CROSSINGS FOR "early" GROUP
# MEAN HEADING = -3.46773194047
# SEM HEADING = 1.38136546792
# 766 CROSSINGS FOR "late" GROUP
# MEAN HEADING = 3.56049442173
# SEM HEADING = 1.46905785623
# MAKING PLOT FOR CG "fruitfly_0.4mps_checkerboard_floor_on_th10.0_chosen0"
# 1158 CROSSINGS FOR "early" GROUP
# MEAN HEADING = -2.10852052602
# SEM HEADING = 1.07633610887
# 828 CROSSINGS FOR "late" GROUP
# MEAN HEADING = 2.95921122085
# SEM HEADING = 1.29812126068
# MAKING PLOT FOR CG "fruitfly_0.6mps_checkerboard_floor_on_th10.0_chosen0"
# 394 CROSSINGS FOR "early" GROUP
# MEAN HEADING = -3.05857983607
# SEM HEADING = 1.7763065024
# 294 CROSSINGS FOR "late" GROUP
# MEAN HEADING = 3.97237950259
# SEM HEADING = 2.0342777554
# MAKING PLOT FOR CG "mosquito_0.4mps_checkerboard_floor_on_th430.0_chosen0"
# 125 CROSSINGS FOR "early" GROUP
# MEAN HEADING = -1.65770368992
# SEM HEADING = 3.70528311306
# 143 CROSSINGS FOR "late" GROUP
# MEAN HEADING = 1.38913194563
# SEM HEADING = 3.31600722296

# %% [markdown]
# # Infotaxis simulations
#
# Before analysis can be done on the infotaxis trajectories, they must be created by running the following simulations. Note: make sure that you have database named infotaxis_db in your MySQL DBMS, and that it has been populated from the file infotaxis_db.sql.

# %% [markdown]
# ### Infotaxis with different source emission rates and diffusivities

# %%
from scripts.infotaxis.generate_wind_tunnel_discretized_matched_trials_one_for_one import main

SCRIPTNOTES = 'Run for all experiments and odor states with d = 0.09 m^2/s, r = 1000.'
INSECT_PARAMS = {
    'r': 1000,  # source emission rate
    'd': 0.09,  # diffusivity (m^2/s)
    'a': .002,  # searcher size (m)
    'tau': 10000  # particle lifetime (s)
    }

main(INSECT_PARAMS=INSECT_PARAMS, SCRIPTNOTES=SCRIPTNOTES)
# Out:
# CONNECTED TO INFOTAXIS PRODUCTION DATABASE
# Are you sure you want to connect to the production database [y or n]?y
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "on"...
# logprob_odor.py:78: RuntimeWarning: divide by zero encountered in divide
#   rate = (a*r/dr) * np.exp(exponent)
# /Users/rkp/anaconda/envs/py2/lib/python2.7/site-packages/sqlalchemy/engine/default.py:470: Warning: Data truncated for column 'hxyz' at row 1
#   cursor.execute(statement, parameters)
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "afterodor"...

# %%
from scripts.infotaxis.identify_plume_crossings import main

main(SIM_PREFIX='wind_tunnel_discretized_matched_r1000_d0.09')
# Out:
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_mosquito_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_mosquito_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.09_mosquito_0.4mps_checkerboard_floor_odor_afterodor"

# %%
from scripts.infotaxis.generate_wind_tunnel_discretized_matched_trials_one_for_one import main

SCRIPTNOTES = 'Run for all experiments and odor states with d = 0.2 m^2/s, r = 1000.'
INSECT_PARAMS = {
    'r': 1000,  # source emission rate
    'd': 0.2,  # diffusivity (m^2/s)
    'a': .002,  # searcher size (m)
    'tau': 10000  # particle lifetime (s)
    }

main(INSECT_PARAMS=INSECT_PARAMS, SCRIPTNOTES=SCRIPTNOTES)
# Out:
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "afterodor"...

# %%
from scripts.infotaxis.identify_plume_crossings import main

main(SIM_PREFIX='wind_tunnel_discretized_matched_r1000_d0.2')
# Out:
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.3mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.3mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.3mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.4mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.6mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.6mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_fruitfly_0.6mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_mosquito_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_mosquito_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r1000_d0.2_mosquito_0.4mps_checkerboard_floor_odor_afterodor"

# %%
from scripts.infotaxis.generate_wind_tunnel_discretized_matched_trials_one_for_one import main

SCRIPTNOTES = 'Run for all experiments and odor states with d = 0.09 m^2/s, r = 500.'
INSECT_PARAMS = {
    'r': 500,  # source emission rate
    'd': 0.09,  # diffusivity (m^2/s)
    'a': .002,  # searcher size (m)
    'tau': 10000  # particle lifetime (s)
    }

main(INSECT_PARAMS=INSECT_PARAMS, SCRIPTNOTES=SCRIPTNOTES)
# Out:
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "afterodor"...

# %%
from scripts.infotaxis.identify_plume_crossings import main

main(SIM_PREFIX='wind_tunnel_discretized_matched_r500_d0.09')
# Out:
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_mosquito_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_mosquito_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r500_d0.09_mosquito_0.4mps_checkerboard_floor_odor_afterodor"

# %%
from scripts.infotaxis.generate_wind_tunnel_discretized_matched_trials_one_for_one import main

SCRIPTNOTES = 'Run for all experiments and odor states with d = 0.09 m^2/s, r = 100.'
INSECT_PARAMS = {
    'r': 100,  # source emission rate
    'd': 0.09,  # diffusivity (m^2/s)
    'a': .002,  # searcher size (m)
    'tau': 10000  # particle lifetime (s)
    }

main(INSECT_PARAMS=INSECT_PARAMS, SCRIPTNOTES=SCRIPTNOTES)
# Out:
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "afterodor"...

# %%
from scripts.infotaxis.identify_plume_crossings import main

main(SIM_PREFIX='wind_tunnel_discretized_matched_r100_d0.09')
# Out:
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_mosquito_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_mosquito_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r100_d0.09_mosquito_0.4mps_checkerboard_floor_odor_afterodor"

# %%
from scripts.infotaxis.generate_wind_tunnel_discretized_matched_trials_one_for_one import main

SCRIPTNOTES = 'Run for all experiments and odor states with d = 0.09 m^2/s, r = 2000.'
INSECT_PARAMS = {
    'r': 2000,  # source emission rate
    'd': 0.09,  # diffusivity (m^2/s)
    'a': .002,  # searcher size (m)
    'tau': 10000  # particle lifetime (s)
    }

main(INSECT_PARAMS=INSECT_PARAMS, SCRIPTNOTES=SCRIPTNOTES)
# Out:
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.3mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.4mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "fruitfly_0.6mps_checkerboard_floor" with odor "afterodor"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "on"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "none"...
# Running simulation for expt "mosquito_0.4mps_checkerboard_floor" with odor "afterodor"...

# %%
from scripts.infotaxis.identify_plume_crossings import main

main(SIM_PREFIX='wind_tunnel_discretized_matched_r2000_d0.09')
# Out:
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.3mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.4mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_fruitfly_0.6mps_checkerboard_floor_odor_afterodor"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_mosquito_0.4mps_checkerboard_floor_odor_on"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_mosquito_0.4mps_checkerboard_floor_odor_none"
# Identifying crossings from simulation: "wind_tunnel_discretized_matched_r2000_d0.09_mosquito_0.4mps_checkerboard_floor_odor_afterodor"
